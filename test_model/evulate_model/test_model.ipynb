# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import os

# Đọc dữ liệu
print("Đang đọc dữ liệu...")
csv_files = [f for f in os.listdir("weather_archive") if f.endswith('.csv')]
if not csv_files:
    raise FileNotFoundError("Không tìm thấy file CSV trong thư mục weather_archive")

data_file = os.path.join("weather_archive", csv_files[0])
df = pd.read_csv(data_file)

# Kiểm tra và làm sạch dữ liệu
print("Đang xử lý dữ liệu...")
df['Date'] = pd.to_datetime(df['Date'])
df = df.dropna(subset=['Temp_Max', 'Temp_Min', 'Weather_Code'])
df['Weather_Code'] = df['Weather_Code'].astype(int)

# Định nghĩa các mã thời tiết hợp lệ và mô tả
valid_weather_codes = [0, 1, 2, 3, 45, 48, 51, 53, 55, 56, 57, 61, 63, 65, 66, 67, 71, 73, 75, 77, 80, 81, 82, 85, 86, 95, 96, 99]
weather_code_descriptions = {
    0: "Clear sky",
    1: "Mainly clear",
    2: "Partly cloudy",
    3: "Overcast",
    45: "Fog",
    48: "Depositing rime fog",
    51: "Drizzle: Light intensity",
    53: "Drizzle: Moderate intensity",
    55: "Drizzle: Dense intensity",
    56: "Freezing drizzle: Light",
    57: "Freezing drizzle: Dense",
    61: "Rain: Slight",
    63: "Rain: Moderate",
    65: "Rain: Heavy",
    66: "Freezing rain: Light",
    67: "Freezing rain: Heavy",
    71: "Snow fall: Slight",
    73: "Snow fall: Moderate",
    75: "Snow fall: Heavy",
    77: "Snow grains",
    80: "Rain showers: Slight",
    81: "Rain showers: Moderate",
    82: "Rain showers: Violent",
    85: "Snow showers: Slight",
    86: "Snow showers: Heavy",
    95: "Thunderstorm: Slight or moderate",
    96: "Thunderstorm with slight hail",
    99: "Thunderstorm with heavy hail"
}

# Hàm tìm mã thời tiết gần nhất
def find_nearest_weather_code(pred_code, valid_codes=valid_weather_codes):
    valid_codes = np.array(valid_codes)
    idx = (np.abs(valid_codes - pred_code)).argmin()
    return valid_codes[idx]

# Thêm các đặc trưng thời gian
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['DayOfYear'] = df['Date'].dt.dayofyear
df['DayOfWeek'] = df['Date'].dt.dayofweek

# Mã hóa tỉnh thành
le_province = LabelEncoder()
df['Province_Code'] = le_province.fit_transform(df['Province'])

# Tạo thư mục lưu kết quả đánh giá
os.makedirs('model_evaluation', exist_ok=True)

# Lấy danh sách các tỉnh thành
provinces = df['Province'].unique()

print(f"\n{'='*50}")
print(f"ĐÁNH GIÁ MÔ HÌNH RANDOM FOREST CHO {len(provinces)} TỈNH THÀNH")
print(f"{'='*50}")

# Tạo DataFrame để lưu kết quả đánh giá
evaluation_results = []

for province_name in provinces:
    print(f"\nĐang xử lý cho tỉnh: {province_name}")
    
    # Lọc dữ liệu theo tỉnh
    province_data = df[df['Province'] == province_name].sort_values('Date')
    
    # Kiểm tra xem có đủ dữ liệu không
    if len(province_data) < 14:
        print(f"  Bỏ qua tỉnh {province_name}: không đủ dữ liệu")
        continue
    
    # Tạo các đặc trưng với độ trễ
    for lag in range(1, 8):
        province_data[f'Temp_Max_Lag{lag}'] = province_data['Temp_Max'].shift(lag)
        province_data[f'Temp_Min_Lag{lag}'] = province_data['Temp_Min'].shift(lag)
        province_data[f'Weather_Code_Lag{lag}'] = province_data['Weather_Code'].shift(lag)
    
    # Tạo đặc trưng trung bình động
    for window in [3, 5, 7]:
        province_data[f'Temp_Max_Roll{window}'] = province_data['Temp_Max'].rolling(window=window).mean()
        province_data[f'Temp_Min_Roll{window}'] = province_data['Temp_Min'].rolling(window=window).mean()
        province_data[f'Weather_Code_Roll{window}'] = province_data['Weather_Code'].rolling(window=window).mean()
    
    # Loại bỏ các hàng có giá trị NaN
    province_data = province_data.dropna()
    
    if len(province_data) < 10:
        print(f"  Bỏ qua tỉnh {province_name}: không đủ dữ liệu sau khi tạo đặc trưng")
        continue
    
    # Chia tập dữ liệu train/test (80/20)
    train_size = int(len(province_data) * 0.8)
    train_data = province_data.iloc[:train_size]
    test_data = province_data.iloc[train_size:]
    
    # Tạo các đặc trưng cho dự đoán
    feature_cols = [col for col in train_data.columns if col.startswith(('Temp_Max_Lag', 'Temp_Min_Lag', 
                                                                        'Weather_Code_Lag', 'Temp_Max_Roll', 
                                                                        'Temp_Min_Roll', 'Weather_Code_Roll'))]
    feature_cols += ['Month', 'Day', 'DayOfYear', 'DayOfWeek']
    
    X_train = train_data[feature_cols]
    X_test = test_data[feature_cols]
    y_train_temp_max = train_data['Temp_Max']
    y_test_temp_max = test_data['Temp_Max']
    y_train_temp_min = train_data['Temp_Min']
    y_test_temp_min = test_data['Temp_Min']
    y_train_weather_code = train_data['Weather_Code']
    y_test_weather_code = test_data['Weather_Code']
    
    # Huấn luyện mô hình Random Forest
    models = {
        'temp_max': RandomForestRegressor(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, random_state=42, n_jobs=-1),
        'temp_min': RandomForestRegressor(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, random_state=42, n_jobs=-1),
        'weather_code': RandomForestRegressor(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, random_state=42, n_jobs=-1)
    }
    
    # Huấn luyện và đánh giá từng mô hình
    print(f"\nKết quả đánh giá cho {province_name}:")
    print("-" * 40)
    
    province_eval = {'Province': province_name}
    
    for target, model in models.items():
        if target == 'temp_max':
            y_train = y_train_temp_max
            y_test = y_test_temp_max
            target_name = "Nhiệt độ cao nhất"
        elif target == 'temp_min':
            y_train = y_train_temp_min
            y_test = y_test_temp_min
            target_name = "Nhiệt độ thấp nhất"
        else:
            y_train = y_train_weather_code
            y_test = y_test_weather_code
            target_name = "Mã thời tiết"
        
        # Huấn luyện mô hình
        model.fit(X_train, y_train)
        
        # Dự đoán trên tập test
        y_pred = model.predict(X_test)
        
        # Tính các metrics
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mae = mean_absolute_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        
        # Lưu kết quả
        province_eval[f'{target}_rmse'] = rmse
        province_eval[f'{target}_mae'] = mae
        province_eval[f'{target}_r2'] = r2
        
        # In kết quả
        print(f"{target_name}:")
        print(f"  RMSE: {rmse:.4f}")
        print(f"  MAE:  {mae:.4f}")
        print(f"  R2:   {r2:.4f}")
    
    print("-" * 40)
    
    # Thêm kết quả đánh giá của tỉnh vào danh sách
    evaluation_results.append(province_eval)

# Chuyển kết quả đánh giá thành DataFrame
evaluation_df = pd.DataFrame(evaluation_results)

# Lưu kết quả đánh giá
evaluation_df.to_csv('model_evaluation/random_forest_evaluation.csv', index=False)

print(f"\n{'='*50}")
print("ĐÃ HOÀN THÀNH ĐÁNH GIÁ MÔ HÌNH!")
print(f"Kết quả được lưu trong file: 'model_evaluation/random_forest_evaluation.csv'")
print(f"{'='*50}")

# In thống kê tổng quan
print("\nThống kê tổng quan về RMSE:")
print("-" * 40)
print(evaluation_df[['Province', 'temp_max_rmse', 'temp_min_rmse', 'weather_code_rmse']].describe())
# Out:
# Đang đọc dữ liệu...
# Đang xử lý dữ liệu...
#
# ==================================================
# ĐÁNH GIÁ MÔ HÌNH RANDOM FOREST CHO 63 TỈNH THÀNH
# ==================================================
#
# Đang xử lý cho tỉnh: An Giang
#
# Kết quả đánh giá cho An Giang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.7695
#   MAE:  2.5988
#   R2:   -0.5356
# Nhiệt độ thấp nhất:
#   RMSE: 0.8243
#   MAE:  0.7230
#   R2:   0.2041
# Mã thời tiết:
#   RMSE: 19.7299
#   MAE:  18.8411
#   R2:   -12.2225
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bà Rịa - Vũng Tàu
#
# Kết quả đánh giá cho Bà Rịa - Vũng Tàu:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 1.5946
#   MAE:  1.3127
#   R2:   -1.7005
# Nhiệt độ thấp nhất:
#   RMSE: 1.0360
#   MAE:  0.8927
#   R2:   0.2232
# Mã thời tiết:
#   RMSE: 24.8939
#   MAE:  24.0559
#   R2:   -0.3715
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bạc Liêu
#
# Kết quả đánh giá cho Bạc Liêu:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7998
#   MAE:  1.8592
#   R2:   -1.0274
# Nhiệt độ thấp nhất:
#   RMSE: 0.8199
#   MAE:  0.7284
#   R2:   0.0019
# Mã thời tiết:
#   RMSE: 10.4924
#   MAE:  10.3717
#   R2:   -6.3199
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bắc Giang
#
# Kết quả đánh giá cho Bắc Giang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.1335
#   MAE:  1.9427
#   R2:   -0.1184
# Nhiệt độ thấp nhất:
#   RMSE: 1.8553
#   MAE:  1.6930
#   R2:   -1.1643
# Mã thời tiết:
#   RMSE: 22.7694
#   MAE:  21.0174
#   R2:   0.2667
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bắc Kạn
#
# Kết quả đánh giá cho Bắc Kạn:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7823
#   MAE:  2.0252
#   R2:   -0.4385
# Nhiệt độ thấp nhất:
#   RMSE: 2.3667
#   MAE:  2.0279
#   R2:   -1.2956
# Mã thời tiết:
#   RMSE: 20.3258
#   MAE:  13.0280
#   R2:   0.0562
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bắc Ninh
#
# Kết quả đánh giá cho Bắc Ninh:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.3359
#   MAE:  2.1041
#   R2:   -0.0315
# Nhiệt độ thấp nhất:
#   RMSE: 1.7653
#   MAE:  1.5892
#   R2:   -0.8271
# Mã thời tiết:
#   RMSE: 34.0314
#   MAE:  32.0950
#   R2:   -0.5162
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bến Tre
#
# Kết quả đánh giá cho Bến Tre:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.5148
#   MAE:  2.7718
#   R2:   -1.7317
# Nhiệt độ thấp nhất:
#   RMSE: 0.7457
#   MAE:  0.6518
#   R2:   0.0114
# Mã thời tiết:
#   RMSE: 15.0727
#   MAE:  12.5175
#   R2:   -7.1604
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bình Định
#
# Kết quả đánh giá cho Bình Định:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.3711
#   MAE:  1.6147
#   R2:   -0.0516
# Nhiệt độ thấp nhất:
#   RMSE: 1.1428
#   MAE:  1.0991
#   R2:   -10.6615
# Mã thời tiết:
#   RMSE: 24.6928
#   MAE:  23.5372
#   R2:   0.1239
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bình Dương
#
# Kết quả đánh giá cho Bình Dương:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.4911
#   MAE:  2.2953
#   R2:   -0.6821
# Nhiệt độ thấp nhất:
#   RMSE: 0.4747
#   MAE:  0.3612
#   R2:   -0.6285
# Mã thời tiết:
#   RMSE: 4.7293
#   MAE:  3.1487
#   R2:   -0.3979
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bình Phước
#
# Kết quả đánh giá cho Bình Phước:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.7165
#   MAE:  2.3215
#   R2:   -0.3627
# Nhiệt độ thấp nhất:
#   RMSE: 0.6773
#   MAE:  0.5194
#   R2:   -0.6766
# Mã thời tiết:
#   RMSE: 7.3005
#   MAE:  6.1662
#   R2:   -1.1630
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Bình Thuận
#
# Kết quả đánh giá cho Bình Thuận:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.4624
#   MAE:  1.8973
#   R2:   -1.4624
# Nhiệt độ thấp nhất:
#   RMSE: 1.3572
#   MAE:  1.1111
#   R2:   -2.5588
# Mã thời tiết:
#   RMSE: 22.6643
#   MAE:  17.9465
#   R2:   -0.0370
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Cà Mau
#
# Kết quả đánh giá cho Cà Mau:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.3732
#   MAE:  2.1518
#   R2:   -0.9664
# Nhiệt độ thấp nhất:
#   RMSE: 0.6025
#   MAE:  0.5312
#   R2:   -1.0909
# Mã thời tiết:
#   RMSE: 7.1472
#   MAE:  6.5212
#   R2:   -1.2171
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Cần Thơ
#
# Kết quả đánh giá cho Cần Thơ:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.7131
#   MAE:  2.6391
#   R2:   -1.1988
# Nhiệt độ thấp nhất:
#   RMSE: 0.7022
#   MAE:  0.5091
#   R2:   0.3756
# Mã thời tiết:
#   RMSE: 21.6689
#   MAE:  15.1701
#   R2:   0.1266
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Cao Bằng
#
# Kết quả đánh giá cho Cao Bằng:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.9334
#   MAE:  2.9443
#   R2:   -0.9340
# Nhiệt độ thấp nhất:
#   RMSE: 2.3322
#   MAE:  1.8834
#   R2:   -0.7785
# Mã thời tiết:
#   RMSE: 25.7962
#   MAE:  24.4899
#   R2:   -0.2363
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Đà Nẵng
#
# Kết quả đánh giá cho Đà Nẵng:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.3606
#   MAE:  2.2676
#   R2:   -0.3591
# Nhiệt độ thấp nhất:
#   RMSE: 1.7341
#   MAE:  1.6600
#   R2:   -14.9958
# Mã thời tiết:
#   RMSE: 18.3626
#   MAE:  16.4263
#   R2:   0.0853
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Đắk Lắk
#
# Kết quả đánh giá cho Đắk Lắk:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.7507
#   MAE:  2.1615
#   R2:   -0.3057
# Nhiệt độ thấp nhất:
#   RMSE: 1.1946
#   MAE:  1.0172
#   R2:   -3.1293
# Mã thời tiết:
#   RMSE: 20.6847
#   MAE:  19.6368
#   R2:   0.0190
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Đắk Nông
#
# Kết quả đánh giá cho Đắk Nông:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 4.5064
#   MAE:  2.7312
#   R2:   -0.2738
# Nhiệt độ thấp nhất:
#   RMSE: 0.7282
#   MAE:  0.6465
#   R2:   -3.9834
# Mã thời tiết:
#   RMSE: 24.7791
#   MAE:  16.2391
#   R2:   -0.1254
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Điện Biên
#
# Kết quả đánh giá cho Điện Biên:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.8110
#   MAE:  2.7489
#   R2:   -0.4087
# Nhiệt độ thấp nhất:
#   RMSE: 0.9737
#   MAE:  0.8403
#   R2:   -0.6576
# Mã thời tiết:
#   RMSE: 31.0949
#   MAE:  27.7359
#   R2:   -0.0869
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Đồng Nai
#
# Kết quả đánh giá cho Đồng Nai:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.6709
#   MAE:  2.6701
#   R2:   -1.0612
# Nhiệt độ thấp nhất:
#   RMSE: 0.6261
#   MAE:  0.5407
#   R2:   -0.1894
# Mã thời tiết:
#   RMSE: 22.6325
#   MAE:  21.7321
#   R2:   -14.5409
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Đồng Tháp
#
# Kết quả đánh giá cho Đồng Tháp:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 4.1410
#   MAE:  3.3744
#   R2:   -0.6949
# Nhiệt độ thấp nhất:
#   RMSE: 0.8516
#   MAE:  0.6399
#   R2:   0.3502
# Mã thời tiết:
#   RMSE: 20.2235
#   MAE:  11.1701
#   R2:   0.2392
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Gia Lai
#
# Kết quả đánh giá cho Gia Lai:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.6704
#   MAE:  1.8842
#   R2:   0.0677
# Nhiệt độ thấp nhất:
#   RMSE: 0.4924
#   MAE:  0.4133
#   R2:   -0.9935
# Mã thời tiết:
#   RMSE: 26.6912
#   MAE:  23.8938
#   R2:   -23.1990
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hà Giang
#
# Kết quả đánh giá cho Hà Giang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.5927
#   MAE:  2.2836
#   R2:   -0.1283
# Nhiệt độ thấp nhất:
#   RMSE: 1.6523
#   MAE:  1.6090
#   R2:   -0.2223
# Mã thời tiết:
#   RMSE: 29.2900
#   MAE:  27.2485
#   R2:   -0.2540
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hà Nam
#
# Kết quả đánh giá cho Hà Nam:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7353
#   MAE:  2.4889
#   R2:   -0.1261
# Nhiệt độ thấp nhất:
#   RMSE: 2.0045
#   MAE:  1.8428
#   R2:   -0.9083
# Mã thời tiết:
#   RMSE: 26.2619
#   MAE:  18.8652
#   R2:   -0.0680
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hà Nội
#
# Kết quả đánh giá cho Hà Nội:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7895
#   MAE:  1.8084
#   R2:   -0.2239
# Nhiệt độ thấp nhất:
#   RMSE: 2.6147
#   MAE:  2.4070
#   R2:   -3.8555
# Mã thời tiết:
#   RMSE: 27.7669
#   MAE:  21.2063
#   R2:   -0.0942
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hà Tĩnh
#
# Kết quả đánh giá cho Hà Tĩnh:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 1.8552
#   MAE:  1.6664
#   R2:   -0.2797
# Nhiệt độ thấp nhất:
#   RMSE: 0.8855
#   MAE:  0.6115
#   R2:   0.2420
# Mã thời tiết:
#   RMSE: 27.6757
#   MAE:  24.4190
#   R2:   -0.0273
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hải Dương
#
# Kết quả đánh giá cho Hải Dương:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.3122
#   MAE:  2.1131
#   R2:   -0.1843
# Nhiệt độ thấp nhất:
#   RMSE: 1.9479
#   MAE:  1.7193
#   R2:   -2.2552
# Mã thời tiết:
#   RMSE: 28.9116
#   MAE:  21.9271
#   R2:   -0.2944
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hải Phòng
#
# Kết quả đánh giá cho Hải Phòng:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 1.3114
#   MAE:  1.2684
#   R2:   0.0475
# Nhiệt độ thấp nhất:
#   RMSE: 1.8835
#   MAE:  1.6125
#   R2:   -2.1406
# Mã thời tiết:
#   RMSE: 22.7911
#   MAE:  11.8377
#   R2:   -0.3229
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hậu Giang
#
# Kết quả đánh giá cho Hậu Giang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.8249
#   MAE:  2.7221
#   R2:   -1.3178
# Nhiệt độ thấp nhất:
#   RMSE: 0.5832
#   MAE:  0.4490
#   R2:   0.4421
# Mã thời tiết:
#   RMSE: 20.6207
#   MAE:  19.6680
#   R2:   0.2618
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hòa Bình
#
# Kết quả đánh giá cho Hòa Bình:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7793
#   MAE:  2.6803
#   R2:   0.3723
# Nhiệt độ thấp nhất:
#   RMSE: 1.2481
#   MAE:  1.1013
#   R2:   -0.4673
# Mã thời tiết:
#   RMSE: 33.0050
#   MAE:  29.7343
#   R2:   -0.4202
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Hưng Yên
#
# Kết quả đánh giá cho Hưng Yên:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.3525
#   MAE:  2.0536
#   R2:   -0.1158
# Nhiệt độ thấp nhất:
#   RMSE: 1.9824
#   MAE:  1.7955
#   R2:   -1.8282
# Mã thời tiết:
#   RMSE: 29.5284
#   MAE:  24.5794
#   R2:   -0.4493
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Khánh Hòa
#
# Kết quả đánh giá cho Khánh Hòa:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.5157
#   MAE:  1.9891
#   R2:   -1.8283
# Nhiệt độ thấp nhất:
#   RMSE: 0.5226
#   MAE:  0.4604
#   R2:   -4.5053
# Mã thời tiết:
#   RMSE: 25.5346
#   MAE:  22.1115
#   R2:   0.1322
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Kiên Giang
#
# Kết quả đánh giá cho Kiên Giang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.9977
#   MAE:  1.7824
#   R2:   -0.2401
# Nhiệt độ thấp nhất:
#   RMSE: 0.6983
#   MAE:  0.6132
#   R2:   0.2718
# Mã thời tiết:
#   RMSE: 12.6075
#   MAE:  10.1517
#   R2:   -10.5515
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Kon Tum
#
# Kết quả đánh giá cho Kon Tum:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 4.0686
#   MAE:  2.1584
#   R2:   0.0084
# Nhiệt độ thấp nhất:
#   RMSE: 0.8054
#   MAE:  0.7101
#   R2:   -0.0781
# Mã thời tiết:
#   RMSE: 23.4760
#   MAE:  23.2137
#   R2:   -0.1421
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Lai Châu
#
# Kết quả đánh giá cho Lai Châu:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.2475
#   MAE:  1.5852
#   R2:   0.1159
# Nhiệt độ thấp nhất:
#   RMSE: 1.0500
#   MAE:  0.8753
#   R2:   -8.7059
# Mã thời tiết:
#   RMSE: 6.7143
#   MAE:  5.9401
#   R2:   -0.8296
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Lâm Đồng
#
# Kết quả đánh giá cho Lâm Đồng:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.5640
#   MAE:  2.6804
#   R2:   -1.4875
# Nhiệt độ thấp nhất:
#   RMSE: 0.8532
#   MAE:  0.6671
#   R2:   -2.1161
# Mã thời tiết:
#   RMSE: 23.5606
#   MAE:  22.8031
#   R2:   0.0013
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Lạng Sơn
#
# Kết quả đánh giá cho Lạng Sơn:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.2224
#   MAE:  1.8777
#   R2:   -0.2122
# Nhiệt độ thấp nhất:
#   RMSE: 2.1855
#   MAE:  1.8675
#   R2:   -1.4702
# Mã thời tiết:
#   RMSE: 22.6520
#   MAE:  22.1109
#   R2:   0.3527
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Lào Cai
#
# Kết quả đánh giá cho Lào Cai:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.2842
#   MAE:  2.9977
#   R2:   -0.5500
# Nhiệt độ thấp nhất:
#   RMSE: 1.3530
#   MAE:  1.2510
#   R2:   -0.5545
# Mã thời tiết:
#   RMSE: 29.6441
#   MAE:  26.2817
#   R2:   -0.1651
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Long An
#
# Kết quả đánh giá cho Long An:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.0284
#   MAE:  2.0545
#   R2:   -0.7645
# Nhiệt độ thấp nhất:
#   RMSE: 0.8470
#   MAE:  0.6778
#   R2:   0.1182
# Mã thời tiết:
#   RMSE: 23.6975
#   MAE:  15.5929
#   R2:   -0.0585
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Nam Định
#
# Kết quả đánh giá cho Nam Định:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.1079
#   MAE:  1.9179
#   R2:   -0.1397
# Nhiệt độ thấp nhất:
#   RMSE: 1.9756
#   MAE:  1.7252
#   R2:   -1.6062
# Mã thời tiết:
#   RMSE: 24.3746
#   MAE:  19.4479
#   R2:   -0.0020
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Nghệ An
#
# Kết quả đánh giá cho Nghệ An:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7116
#   MAE:  2.4091
#   R2:   -0.3606
# Nhiệt độ thấp nhất:
#   RMSE: 2.0188
#   MAE:  1.5215
#   R2:   -0.6937
# Mã thời tiết:
#   RMSE: 24.4642
#   MAE:  22.3745
#   R2:   0.1808
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Ninh Bình
#
# Kết quả đánh giá cho Ninh Bình:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.5838
#   MAE:  2.1835
#   R2:   -0.3305
# Nhiệt độ thấp nhất:
#   RMSE: 1.8769
#   MAE:  1.6198
#   R2:   -1.4560
# Mã thời tiết:
#   RMSE: 27.5764
#   MAE:  23.5000
#   R2:   -0.0836
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Ninh Thuận
#
# Kết quả đánh giá cho Ninh Thuận:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 4.5115
#   MAE:  3.3851
#   R2:   -1.2549
# Nhiệt độ thấp nhất:
#   RMSE: 1.5886
#   MAE:  1.3494
#   R2:   -6.2853
# Mã thời tiết:
#   RMSE: 29.0474
#   MAE:  28.5548
#   R2:   -0.6246
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Phú Thọ
#
# Kết quả đánh giá cho Phú Thọ:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.6358
#   MAE:  2.4188
#   R2:   0.0586
# Nhiệt độ thấp nhất:
#   RMSE: 1.4069
#   MAE:  1.3171
#   R2:   -1.0669
# Mã thời tiết:
#   RMSE: 28.9673
#   MAE:  26.2246
#   R2:   -0.0985
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Phú Yên
#
# Kết quả đánh giá cho Phú Yên:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 1.5532
#   MAE:  1.2652
#   R2:   0.0939
# Nhiệt độ thấp nhất:
#   RMSE: 0.9935
#   MAE:  0.8600
#   R2:   -2.8555
# Mã thời tiết:
#   RMSE: 21.6603
#   MAE:  21.3645
#   R2:   0.1754
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Quảng Bình
#
# Kết quả đánh giá cho Quảng Bình:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.4191
#   MAE:  1.9853
#   R2:   -0.4756
# Nhiệt độ thấp nhất:
#   RMSE: 1.7632
#   MAE:  1.7075
#   R2:   -10.4979
# Mã thời tiết:
#   RMSE: 22.7461
#   MAE:  20.3089
#   R2:   -0.2039
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Quảng Nam
#
# Kết quả đánh giá cho Quảng Nam:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.0360
#   MAE:  2.3390
#   R2:   0.0550
# Nhiệt độ thấp nhất:
#   RMSE: 0.7453
#   MAE:  0.5760
#   R2:   -1.2256
# Mã thời tiết:
#   RMSE: 15.8930
#   MAE:  14.4229
#   R2:   0.4410
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Quảng Ngãi
#
# Kết quả đánh giá cho Quảng Ngãi:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.4374
#   MAE:  2.0323
#   R2:   0.0608
# Nhiệt độ thấp nhất:
#   RMSE: 0.8578
#   MAE:  0.7321
#   R2:   -7.5960
# Mã thời tiết:
#   RMSE: 24.5505
#   MAE:  24.0098
#   R2:   -0.0593
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Quảng Ninh
#
# Kết quả đánh giá cho Quảng Ninh:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 0.8116
#   MAE:  0.7236
#   R2:   -0.9987
# Nhiệt độ thấp nhất:
#   RMSE: 1.4226
#   MAE:  1.2736
#   R2:   -0.8291
# Mã thời tiết:
#   RMSE: 33.1309
#   MAE:  24.0322
#   R2:   -0.4734
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Quảng Trị
#
# Kết quả đánh giá cho Quảng Trị:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.3140
#   MAE:  2.8440
#   R2:   -1.1274
# Nhiệt độ thấp nhất:
#   RMSE: 2.3611
#   MAE:  2.3031
#   R2:   -16.5530
# Mã thời tiết:
#   RMSE: 25.3370
#   MAE:  24.7792
#   R2:   -0.4453
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Sóc Trăng
#
# Kết quả đánh giá cho Sóc Trăng:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.2861
#   MAE:  2.3475
#   R2:   -0.6930
# Nhiệt độ thấp nhất:
#   RMSE: 0.9261
#   MAE:  0.7740
#   R2:   0.0410
# Mã thời tiết:
#   RMSE: 23.1803
#   MAE:  21.7657
#   R2:   -0.0073
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Sơn La
#
# Kết quả đánh giá cho Sơn La:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.9661
#   MAE:  2.6353
#   R2:   0.1267
# Nhiệt độ thấp nhất:
#   RMSE: 0.8493
#   MAE:  0.7296
#   R2:   -0.9906
# Mã thời tiết:
#   RMSE: 23.9657
#   MAE:  14.4094
#   R2:   -0.0728
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Tây Ninh
#
# Kết quả đánh giá cho Tây Ninh:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.7812
#   MAE:  2.3047
#   R2:   -0.2601
# Nhiệt độ thấp nhất:
#   RMSE: 0.9419
#   MAE:  0.7523
#   R2:   -0.1860
# Mã thời tiết:
#   RMSE: 15.7413
#   MAE:  14.5918
#   R2:   -6.9015
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Thái Bình
#
# Kết quả đánh giá cho Thái Bình:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 1.7391
#   MAE:  1.5759
#   R2:   0.0007
# Nhiệt độ thấp nhất:
#   RMSE: 2.0421
#   MAE:  1.7622
#   R2:   -2.1726
# Mã thời tiết:
#   RMSE: 25.5891
#   MAE:  23.0360
#   R2:   -0.1043
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Thái Nguyên
#
# Kết quả đánh giá cho Thái Nguyên:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.2230
#   MAE:  2.0079
#   R2:   -0.8384
# Nhiệt độ thấp nhất:
#   RMSE: 2.8976
#   MAE:  2.6393
#   R2:   -3.9110
# Mã thời tiết:
#   RMSE: 24.7462
#   MAE:  20.9142
#   R2:   0.1149
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Thanh Hóa
#
# Kết quả đánh giá cho Thanh Hóa:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.5503
#   MAE:  2.0670
#   R2:   -0.3033
# Nhiệt độ thấp nhất:
#   RMSE: 1.8567
#   MAE:  1.6636
#   R2:   -1.9414
# Mã thời tiết:
#   RMSE: 18.4957
#   MAE:  15.3512
#   R2:   0.3813
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Thừa Thiên Huế
#
# Kết quả đánh giá cho Thừa Thiên Huế:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.7578
#   MAE:  2.4726
#   R2:   -0.4700
# Nhiệt độ thấp nhất:
#   RMSE: 1.3058
#   MAE:  1.1861
#   R2:   -5.3621
# Mã thời tiết:
#   RMSE: 26.4699
#   MAE:  25.1429
#   R2:   -0.2315
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Tiền Giang
#
# Kết quả đánh giá cho Tiền Giang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.6141
#   MAE:  2.6533
#   R2:   -1.3519
# Nhiệt độ thấp nhất:
#   RMSE: 0.8993
#   MAE:  0.6869
#   R2:   0.2353
# Mã thời tiết:
#   RMSE: 23.3590
#   MAE:  16.3284
#   R2:   -0.0980
# ----------------------------------------
#
# Đang xử lý cho tỉnh: TP. Hồ Chí Minh
#
# Kết quả đánh giá cho TP. Hồ Chí Minh:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.7286
#   MAE:  2.6200
#   R2:   -0.4836
# Nhiệt độ thấp nhất:
#   RMSE: 0.7560
#   MAE:  0.6264
#   R2:   0.3981
# Mã thời tiết:
#   RMSE: 18.5552
#   MAE:  14.4344
#   R2:   -11.3669
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Trà Vinh
#
# Kết quả đánh giá cho Trà Vinh:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.9313
#   MAE:  3.2807
#   R2:   -2.3063
# Nhiệt độ thấp nhất:
#   RMSE: 1.1425
#   MAE:  1.0158
#   R2:   0.0970
# Mã thời tiết:
#   RMSE: 12.6626
#   MAE:  12.5348
#   R2:   -4.1129
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Tuyên Quang
#
# Kết quả đánh giá cho Tuyên Quang:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 2.3236
#   MAE:  2.1894
#   R2:   0.1497
# Nhiệt độ thấp nhất:
#   RMSE: 1.4429
#   MAE:  1.2912
#   R2:   -1.0938
# Mã thời tiết:
#   RMSE: 26.7588
#   MAE:  26.3941
#   R2:   0.0207
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Vĩnh Long
#
# Kết quả đánh giá cho Vĩnh Long:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 4.1506
#   MAE:  3.0862
#   R2:   -1.7995
# Nhiệt độ thấp nhất:
#   RMSE: 0.8830
#   MAE:  0.7210
#   R2:   0.2710
# Mã thời tiết:
#   RMSE: 23.4353
#   MAE:  13.9600
#   R2:   0.0314
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Vĩnh Phúc
#
# Kết quả đánh giá cho Vĩnh Phúc:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.1020
#   MAE:  1.8967
#   R2:   -0.5235
# Nhiệt độ thấp nhất:
#   RMSE: 2.2148
#   MAE:  2.0944
#   R2:   -4.2996
# Mã thời tiết:
#   RMSE: 28.5686
#   MAE:  27.1116
#   R2:   -0.0685
# ----------------------------------------
#
# Đang xử lý cho tỉnh: Yên Bái
#
# Kết quả đánh giá cho Yên Bái:
# ----------------------------------------
# Nhiệt độ cao nhất:
#   RMSE: 3.1823
#   MAE:  2.8074
#   R2:   0.0006
# Nhiệt độ thấp nhất:
#   RMSE: 1.7018
#   MAE:  1.5492
#   R2:   -0.3994
# Mã thời tiết:
#   RMSE: 28.2429
#   MAE:  26.7182
#   R2:   -0.0756
# ----------------------------------------
#
# ==================================================
# ĐÃ HOÀN THÀNH ĐÁNH GIÁ MÔ HÌNH!
# Kết quả được lưu trong file: 'model_evaluation/random_forest_evaluation.csv'
# ==================================================
#
# Thống kê tổng quan về RMSE:
# ----------------------------------------
#        temp_max_rmse  temp_min_rmse  weather_code_rmse
# count      63.000000      63.000000          63.000000
# mean        2.965739       1.322062          22.810147
# std         0.797245       0.609764           6.450579
# min         0.811640       0.474742           4.729273
# 25%         2.395102       0.835641          20.473264
# 50%         2.966149       1.142842          23.697527
# 75%         3.670632       1.855983          26.724957
# max         4.511502       2.897554          34.031407
